# %%
import pandas as pd
# %matplotlib notebook
import numpy as np

# %%
from io import StringIO
f = open('./20170520_roro1_testflight/gps_nosecone/LOG00002.TXT', 'r')
gngga_header = 'type,time,latitude,NS,longitude,EW,fix,nb_sat,hdop,alt,alt_unit,height_of_geoid,e1,e2,cksm\n'
gngga = StringIO(gngga_header + '\n'.join(filter(lambda k: k.startswith('$GNGGA'), f)))
gps = pd.read_csv(gngga, index_col='time')

# %%
gps[['latitude', 'longitude', 'alt']].dropna().plot.scatter(x='latitude', y='longitude', c='alt')
# Out:
# <img src="data:image/png;base64,...">

# %%
gps['alt'].dropna().plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
threedee = plt.figure().gca(projection='3d')
lla = gps[['latitude', 'longitude', 'alt']].dropna()
threedee.scatter(lla['latitude'], lla['longitude'], lla['alt'])
threedee.set_xlabel('latitude')
threedee.set_ylabel('longitude')
threedee.set_zlabel('altitudw')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
gps
# Out:
#              type     latitude   NS   longitude   EW  fix  nb_sat   hdop  \
# time
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# NaN        $GNGGA          NaN  NaN         NaN  NaN    0       0  99.99
# ...
